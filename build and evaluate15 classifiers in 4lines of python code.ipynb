# %% [markdown]
# # <span style = "color:green"> Build and evaluate 15 classification models and choose best performimg one with **Five** lines of Python <span>

# %% [markdown]
# Infact it is 18,not 15 as said above provided you have GPU computer locally or use some online facility like cololab

# %% [markdown]
# ## <span style = color:red>And as a bonus get all the hyper parametes fine tuned automatically for the selected model by adding one more line of Python code.<span> And Enjoy !

# %% [markdown]
# Tutorial written by [KV Subbaiah Setty](kvssetty.com) for more such articles see [here](medium.com/@kvssetty)

# %% [markdown]
# This article is aimed towards someone familiar with the concepts of machine learning, and also knows how install new packages using pip/conda and how to use various algorithms in ML libraries like Scikit-Learn,XGBoost,Spacy etc.

# %% [markdown]
# **First let me write down the five lines and also the bonus line of python code as stated above:**
# ```python
# line01  from pycaret.datasets import get_data
# line02  dataset = get_data('credit')
# line03  from pycaret.classification import *
# line04  classification_experiment = setup(data = dataset, target = 'default', session_id=123)
# line05  best_model = compare_models()
# line06  my_tuned_best_model = tune_model(best_model)
# ```

# %%
# first line 
from pycaret.datasets import get_data

# %%
# second line
dataset = get_data('credit')
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1      90000    2          2         2   34      0      0      0      0
# 2      50000    2          2         1   37      0      0      0      0
# 3      50000    1          2         1   57     -1      0     -1      0
# 4      50000    1          1         2   37      0      0      0      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1      0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 2      0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 3      0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
# 4      0  ...    19394.0    19619.0    20024.0    2500.0    1815.0     657.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# ...

# %%
# third line
from pycaret.classification import *

# %%
# Fourt Line 
classification_experiment = setup(data = dataset, target = 'default', session_id=123)
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_f4cf9db6_06f2_11eb_9280_f859715317fd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f4cf9db6_06f2_11eb_9280_f859715317fdlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f4cf9db6_06f2_11eb_9280_f859715317fdrow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_f4cf9db6_06f2_11eb_9280_f859715317fdrow0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_f4cf9db6_06f2_11eb_9280_f859715317fdlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f4cf9db6_06f2_11eb_9280_f859715317fdrow1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
#Fifth line , here is my_best_model ready to predict un-seen data
# voila! amazing

best_model = compare_models()

# my best model appeas to be LDA (Linear Discriminat Analysis)algoritm for the given dataset
# Out:
# <style  type="text/css" >
#     #T_a3cd6c5c_06f3_11eb_8666_f859715317fd th {
#           text-align: left;
# ...

# %% [markdown]
# ### <span style = color:orange>How about bonus point ? sure let's get it<span>

# %%
my_tuned_best_model = tune_model(best_model)
# Out:
# <style  type="text/css" >
# #T_a8b229de_06f3_11eb_b8bc_f859715317fdrow10_col0,#T_a8b229de_06f3_11eb_b8bc_f859715317fdrow10_col1,#T_a8b229de_06f3_11eb_b8bc_f859715317fdrow10_col2,#T_a8b229de_06f3_11eb_b8bc_f859715317fdrow10_col3,#T_a8b229de_06f3_11eb_b8bc_f859715317fdrow10_col4,#T_a8b229de_06f3_11eb_b8bc_f859715317fdrow10_col5,#T_a8b229de_06f3_11eb_b8bc_f859715317fdrow10_col6{
#             background:  yellow;
#         }</style><table id="T_a8b229de_06f3_11eb_b8bc_f859715317fd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %% [markdown]
# **We can we do lot more, but this is what I promised and which is kept.
# Let me save the model for future use.**

# %%
save_model(my_tuned_best_model,'Final LDA Model 05October2020')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %% [markdown]
# ### Summary:

# %% [markdown]
# **These six lines do lot of things behind the hood, mainly:**
#
# 1. A data set is injested in to our project/experiment.
# 2. A data pre-processing pipeline is built automatically to prepare the data suitable to all of our 15 classification models.
# 3. All the 15 models ( which are heterogeneous) are build and evaluated using cross validation and using seven different performance metrics.
# 4. Almost all ML models need hyper parameter tuning,so selected model is tuned for best performnace using a random search techinque.
#
# Note at the end of the tutorial/experiment we saved trained, ready to use LDA model for use in the future for prediction on unseen data using `predict_model().`

# %% [markdown]
# We can see that this tutorial extensively used a new python library (releaed in april 2020) namely **PyCaret**.Updated very shortly to a stable version 2.0.0. In case this is the first time you are coming across **PyCaret**, here are some of its features and other details of the this amazing python library for end-to-end Machine Learning projects.

# %% [markdown]
# # What is PyCaret ?, Why PyCaret ? To whom it is ? And  My views

# %% [markdown]
# - PyCaret is an open source, **low-code (less-code)** machine learning library in Python that automates machine learning workflow. It is an end-to-end machine learning and model management tool that speeds up machine learning experiment cycle and makes you more productive.
# - In comparison with the other open source machine learning libraries, PyCaret is an alternate low-code library that can be used to replace hundreds of lines of code with few words only. This makes experiments exponentially fast and efficient.
# - The the core featues of pycaret are:
#    1. Data pre-processing/preparation for almost all traditonal predictive models.
#    2. Model training and evaluate.
#    3. Analysis of trained models and Interpretability.
#    4. Model selection and finalization.
#    5. Experiment logging
# - PyCaret is essentially a Python wrapper around several popular machine learning libraries and frameworks such as scikit-learn, XGBoost, Microsoft LightGBM, SpaCy,Gensim and many more.
# - Putting it all altogether: Using all the functions and featuters, let’s create a simple command line software that will train multiple models with default parameters, tune hyperparameters of top candidate models, try different ensembling techniques and returns / saves the best model.
# - PyCaret is simple, easy to use and deployment ready. All the steps performed in a ML experiment can be reproduced using a pipeline that is automatically developed and orchestrated in PyCaret as you progress through the experiment. A pipeline can be saved in a binary file format that is transferable across environments.
# - The design and simplicity of PyCaret is inspired by the emerging role of **citizen data scientists**, a term first used by Gartner. Citizen Data Scientists are power users who can perform both simple and moderately sophisticated analytical tasks that would previously have required more expertise and high end professionals. Seasoned data scientists are often difficult to find and expensive to hire but citizen data scientists can be an effective way to mitigate this gap and address data related challenges in business setting.
# - Here is one line summary of pycaret: **PyCaret is an open source, low-code/less-code machine learning library in Python that allows you to go from preparing your data to deploying your model within seconds in your choice of notebook environment.**
# - My personal opinion is that: PyCaret aimed towards someone familiar with the concepts of machine learning and data preparation, and also knows how to use various algorithms in libraries like Scikit-Learn,XGBoost etc,. The ideal user is aware of the need for automation and doesn’t want to spend days or weeks seeking optimal algorithm and its hyperparameters.
# - my perspective on PyCaret:When working with libraries like this one, the classic ones like Scikit-Learn quickly become a part of the past. Not because they’re bad, but these  latest ones are just superior in every single way.
# - Pick up any data science book or online course. I’d bet the only machine learning library covered is Scikit-Learn. It’s a great place to start, don’t get me wrong,it is an amazing library and every ML practioner shoul practice. But we are in 2020 after having some concepts right in our mind, we need something a bit more automated and time-saving to increase our productivity. The answer is packages like **PyCaret**.

# %% [markdown]
# ## References
# [pycaret.org](https://pycaret.org/)
#
# [pycaret docs](https://pycaret.readthedocs.io/en/latest/#module-pycaret.regression)
#
# [PyCaret Source code](https://github.com/pycaret)
